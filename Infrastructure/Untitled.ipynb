# %%
import pandas as pd
import numpy as np

# %%
infranew = pd.read_csv("infra1.csv")

# %%
infranew['no_of_playgrounds'].fillna(0,inplace = True)
infranew.head()
# Out:
#        id  playground  auditorium  theatre  library  laboratory  \
# 0  185131        True       False    False     True        True
# 1  202094        True       False     True     True       False
# 2  197414        True        True    False     True        True
# 3  164444        True       False    False     True        True
# 4  188887        True        True    False     True       False
#
#    conference_hall  health_center  gymnasium_fitness_center  indoor_stadium  \
# 0             True          False                     False           False
# 1            False          False                     False           False
# 2             True           True                     False            True
# 3             True          False                     False           False
# 4             True           True                     False           False
#
#    ...  solar_power_generation  connectivity_nkn  connectivity_nmeict  \
# ...

# %%
infranew.update(infranew.laboratory.astype(int))

# %%
infranew.head()
# Out:
#        id  playground  auditorium  theatre  library  laboratory  \
# 0  185131        True       False    False     True           1
# 1  202094        True       False     True     True           0
# 2  197414        True        True    False     True           1
# 3  164444        True       False    False     True           1
# 4  188887        True        True    False     True           0
#
#    conference_hall  health_center  gymnasium_fitness_center  indoor_stadium  \
# 0             True          False                     False           False
# 1            False          False                     False           False
# 2             True           True                     False            True
# 3             True          False                     False           False
# 4             True           True                     False           False
#
#    ...  solar_power_generation  connectivity_nkn  connectivity_nmeict  \
# ...

# %%
infranew.update(infranew.campus_friendly.astype(int))
infranew.update(infranew.grievance_redressal_mechanism.astype(int))
infranew.update(infranew.vigilance_cell.astype(int))
infranew.update(infranew.vigilance_cell.astype(int))
infranew.update(infranew.e_cell.astype(int))

# %%
infranew.head()
# Out:
#        id  playground  auditorium  theatre  library  laboratory  \
# 0  185131        True       False    False     True           1
# 1  202094        True       False     True     True           0
# 2  197414        True        True    False     True           1
# 3  164444        True       False    False     True           1
# 4  188887        True        True    False     True           0
#
#    conference_hall  health_center  gymnasium_fitness_center  indoor_stadium  \
# 0             True          False                     False           False
# 1            False          False                     False           False
# 2             True           True                     False            True
# 3             True          False                     False           False
# 4             True           True                     False           False
#
#    ...  solar_power_generation  connectivity_nkn  connectivity_nmeict  \
# ...

# %%
infranew.to_csv("infranew2.csv")
